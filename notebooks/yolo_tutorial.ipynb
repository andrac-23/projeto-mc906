# %%
import torch
from torchinfo import summary
from IPython.display import Image

# %%
model = torch.hub.load('ultralytics/yolov5', 'yolov5n', pretrained=True)
summary(model)
# Out:
# Using cache found in /Users/gustavo/.cache/torch/hub/ultralytics_yolov5_master
# YOLOv5 🚀 2024-5-7 Python-3.12.3 torch-2.3.0 CPU
#
# Fusing layers...
# YOLOv5n summary: 213 layers, 1867405 parameters, 0 gradients
# Adding AutoShape...
# ================================================================================
# Layer (type:depth-idx)                                  Param #
# ================================================================================
# AutoShape                                               --
# ├─DetectMultiBackend: 1-1                               --
# │    └─DetectionModel: 2-1                              --
# │    │    └─Sequential: 3-1                             (1,867,405)
# ================================================================================
# Total params: 1,867,405
# Trainable params: 0
# Non-trainable params: 1,867,405
# ================================================================================

# %%
imgs = ['https://ultralytics.com/images/zidane.jpg']  # batch of images
results = model(imgs)
results.print()
results.save()
# Out:
# image 1/1: 720x1280 2 persons, 1 tie
# Speed: 3529.2ms pre-process, 57.6ms inference, 1.2ms NMS per image at shape (1, 3, 384, 640)
# Saved 1 image to runs/detect/exp3

# %%
Image(filename='runs/detect/exp/zidane.jpg')

# %%
results.pandas().xyxy[0]  # img1 predictions (pandas)
# Out:
#          xmin        ymin         xmax        ymax  confidence  class    name
# 0  742.666077   39.551880  1154.486816  715.108704    0.787706      0  person
# 1  134.034515  180.672241   742.213867  720.000000    0.411678      0  person
# 2  435.760406  433.874542   503.000580  712.018311    0.268469     27     tie
